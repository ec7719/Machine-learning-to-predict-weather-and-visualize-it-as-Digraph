# %% [markdown]
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th>4/13/23, 8:17 PM</th>
# <th><blockquote>
# <p>JetBrains Datalore: A powerful environment for Jupyter notebooks.</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>import</strong> sklearn</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > **import** sklearn
# > **import** sklearn
# > **import** pandas **as** pd
# > **from** sklearn.model_selection **import** train_test_split **as**
# > tts
# > **from** sklearn.tree **import** DecisionTreeClassifier **as** dtc
# > **from** sklearn **import** tree
# > **from** sklearn.metrics **import** accuracy_score **as** assc
# > **from** sklearn.linear_model **import** LogisticRegression **as**
# > lr
# > luf=pd.read_csv(**"seattle-weather.csv"**)
# > luf1 = luf.replace({**'weather'**: {**'rain'**: **'1'**, **'sun'**:
# > **'2'**,**'drizzle'**: **'3'**,**'snow'**: **'3'**}
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>luf1</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><table style="width:100%;">
# <colgroup>
# <col style="width: 14%" />
# <col style="width: 14%" />
# <col style="width: 14%" />
# <col style="width: 14%" />
# <col style="width: 14%" />
# <col style="width: 14%" />
# <col style="width: 14%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th></th>
# <th><blockquote>
# <p>date</p>
# </blockquote></th>
# <th>precipitation</th>
# <th>temp max</th>
# <th><blockquote>
# <p>temp min</p>
# </blockquote></th>
# <th><blockquote>
# <p>wind</p>
# </blockquote></th>
# <th>weather</th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>X=luf1.drop(columns=[<strong>'date'</strong>,<strong>'weather'</strong>],axis=0)</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > y=luf1\[**'weather'**\]
# > model=dtc()
# > xtrain,xtest,ytrain,ytest=tts(X,y,test_size=0.2)
# > model.fit(xtrain.values,ytrain)
# >
# > graph=tree.export_graphviz(model,out_file=**'nami.dot'**,feature_names=\[**'precipitaion'**,
# > prediction=model.predict(xtest.values)
# > prediction
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>accurate=assc(ytest,prediction)</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>accurate</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > 0.7679180887372014
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th rowspan="2"><blockquote>
# <p>graph=tree.export_graphviz(model,out_file=<strong>'weather.dot'</strong>,feature_names=[<strong>'precipitaio</strong></p>
# </blockquote></th>
# <th></th>
# </tr>
# <tr class="odd">
# <th rowspan="2"><blockquote>
# <p>1/32</p>
# </blockquote></th>
# </tr>
# <tr class="header">
# <th>https://datalore.jetbrains.com/notebook/y9nB5NCtp0Lp6qpglYrFRR/9g21ZJs82uhh4X8YZMsMJv/</th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
